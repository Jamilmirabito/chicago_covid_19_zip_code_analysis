# %% [markdown]
# # Preparing Chicago Census Data at Zip Code Level

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import censusdata
import requests
import json
from tqdm import tqdm
pd.set_option('display.max_columns', 100)

# %% [markdown]
# ## Preparing ACS5 dataset for use in analysis
# In this dataset, I'll be extracting the following features for use in the analysis:
# - Mean HH size
# - Median Age
# - Percent Hispanic
# - Percent Black
# - Percent White
# - Percent Undocumented
# - Percent Uninsured
# - Percent Unemployed
# - Percent Health Workers

# %%
# import list of variables necessary for analysis
variable_list = list(pd.read_excel('acs_variables.xlsx')['raw_name'].values)
variable_list = [each+'E' for each in variable_list]
variables = ','.join(variable_list)

# %%
# Requests Census data through Census API
request_string = 'https://api.census.gov/data/2018/acs/acs5?get={}&for=zip%20code%20tabulation%20area:*'.format(variables)
data = requests.get(request_string)

# %%
# Convert the data to a dataframe
df = pd.DataFrame(data.json()[1:], columns = data.json()[0])

# %%
df.head()
# Out:
#   B01003_001E B01001_002E B01001_026E B08201_001E B01002_001E B02001_002E  \
# 0       17242        8426        8816        5517        40.5       13026
# 1       38442       18842       19600       12738        42.3       30529
# 2       48814       23939       24875       19233        41.1       37330
# 3        6437        3212        3225        2014        43.3        2627
# 4       27073       13112       13961        8858        42.1       20451
#
#   B02001_003E B03001_003E B03001_004E B05001_006E B05002_026E B08014_002E  \
# 0         145       17184           0        None          59         159
# 1        1070       35925          83        None         214         595
# 2        1930       47551          68        None         205         456
# 3         149        6427           0        None         162          54
# 4         696       26043          56        None          39         493
#
#   B27010_002E B27010_017E B27010_018E B27010_033E B27010_034E B27010_050E  \
# 0        3991         139        3540         314        6666         513
# 1        7827         270        7920         869       16049        1031
# 2       10790         312        9000         827       17967        1249
# 3        1343          41        1229          32        2707         101
# 4        5666           0        5331         414       10834         604
#
#   B27010_051E B27010_066E B19013_001E C24030_023E C24030_050E B23025_001E  \
# 0        2989          42       13092         108         381       13924
# 1        6600          79       16358         347         777       32020
# 2        9608         128       16603         306         839       40180
# 3        1158          23       12832          34         126        5365
# 4        5157           5       19309         155         541       22641
#
#   B23025_002E B23025_003E B23025_004E B08101_001E B08101_009E B08101_017E  \
# 0        5811        5811        3495        3453        3024         170
# 1       13493       13463       11536       11444        7917        2448
# 2       15595       15524       12400       11908       10524         612
# 3        1585        1585        1355        1355        1153           8
# 4        9754        9754        8464        8391        5882        1827
#
#   B08101_025E B08101_033E B08101_041E B08101_049E zip code tabulation area
# 0           0         145          44          70                    00601
# 1          32         407         165         475                    00602
# 2          35         402         285          50                    00603
# 3           0         170           4          20                    00606
# 4          23         176         219         264                    00610

# %%
# Import variable names crosswalk
variable_names = pd.read_excel('acs_variables.xlsx')[['name', 'raw_name']]

# %%
variable_names.raw_name = variable_names.raw_name.apply(lambda x: x+'E')

# %%
crosswalk = variable_names[variable_names.columns[::-1]]

# %%
crosswalk.set_index('raw_name', inplace=True)

# %%
new_names = []
for each in list(df.columns[:-1]):
    new_names.append(crosswalk.loc[each][0])

# %%
new_names.append('ZCTA')

# %%
df.columns = new_names

# %%
df.head()
# Out:
#   totalPop   male female totalHH medianAge race.white race.black hispanic  \
# 0    17242   8426   8816    5517      40.5      13026        145    17184
# 1    38442  18842  19600   12738      42.3      30529       1070    35925
# 2    48814  23939  24875   19233      41.1      37330       1930    47551
# 3     6437   3212   3225    2014      43.3       2627        149     6427
# 4    27073  13112  13961    8858      42.1      20451        696    26043
#
#   hispanic.mex nonCitizen nonCitizenFBLA noVehiclesAvail total__18 unins__18  \
# 0            0       None             59             159      3991       139
# 1           83       None            214             595      7827       270
# 2           68       None            205             456     10790       312
# 3            0       None            162              54      1343        41
# 4           56       None             39             493      5666         0
#
#   total_19_34 unins_19_34 total_35_64 unins_35_64 total_65_ unins_65_  \
# 0        3540         314        6666         513      2989        42
# 1        7920         869       16049        1031      6600        79
# 2        9000         827       17967        1249      9608       128
# 3        1229          32        2707         101      1158        23
# 4        5331         414       10834         604      5157         5
#
#   medianHHInc healthWorkers.f healthWorkers.m employment.pop employment.lf  \
# 0       13092             108             381          13924          5811
# 1       16358             347             777          32020         13493
# 2       16603             306             839          40180         15595
# 3       12832              34             126           5365          1585
# 4       19309             155             541          22641          9754
#
#   employment.clf employment.emp commute.tot commute.drove commute.carpooled  \
# 0           5811           3495        3453          3024               170
# 1          13463          11536       11444          7917              2448
# 2          15524          12400       11908         10524               612
# 3           1585           1355        1355          1153                 8
# 4           9754           8464        8391          5882              1827
#
#   commute.transit commute.walked commute.other commute.workAtHome   ZCTA
# 0               0            145            44                 70  00601
# 1              32            407           165                475  00602
# 2              35            402           285                 50  00603
# 3               0            170             4                 20  00606
# 4              23            176           219                264  00610

# %%
# Restrict df to Chicago zip codes only
chicago_zips = df[(df['ZCTA']>='60601')&(df['ZCTA']<='60701')|(df['ZCTA']=='60707')|(df['ZCTA']=='60827')]

# %%
chicago_zips.shape
# Out:
# (58, 35)

# %%
chicago_zips = chicago_zips.astype(float)
chicago_zips.ZCTA = chicago_zips.ZCTA.astype(int)

# %%
# Create features of interest
chicago_zips['mean_HHsize'] = chicago_zips['totalPop']/chicago_zips['totalHH']
chicago_zips['pctHispanic'] = chicago_zips['hispanic']/chicago_zips['totalPop']
chicago_zips['pctBlack'] = chicago_zips['race.black']/chicago_zips['totalPop']
chicago_zips['pctWhite'] = chicago_zips['race.white']/chicago_zips['totalPop']
chicago_zips['pctUndocumented'] = chicago_zips['nonCitizen']/chicago_zips['totalPop']
chicago_zips['pctUndocumentedFBLA'] = chicago_zips['nonCitizenFBLA']/chicago_zips['totalPop']
chicago_zips['pctUninsured'] = (chicago_zips['unins__18']+chicago_zips['unins_19_34']+chicago_zips['unins_35_64']+
                                chicago_zips['unins_65_'])/(chicago_zips['total__18']+chicago_zips['total_19_34']+
                                                          chicago_zips['total_35_64']+chicago_zips['total_65_'])
chicago_zips['pctUnemployed'] = (chicago_zips['employment.clf']-chicago_zips['employment.emp'])/chicago_zips['totalPop']
chicago_zips['pctHealthWorkers'] = (chicago_zips['healthWorkers.f'] + chicago_zips['healthWorkers.m'])/chicago_zips['totalPop']

# %%
chicago_zips.head()
# Out:
#        totalPop     male   female  totalHH  medianAge  race.white  race.black  \
# 20694   14675.0   7191.0   7484.0   8864.0       34.9     10884.0       818.0
# 20695    1244.0    693.0    551.0    602.0       30.6       848.0        47.0
# 20696    1174.0    573.0    601.0    564.0       28.9       745.0        38.0
# 20697     782.0    369.0    413.0    479.0       32.4       496.0        44.0
# 20698   27519.0  13138.0  14381.0  13865.0       33.9     16843.0      4727.0
#
#        hispanic  hispanic.mex  nonCitizen  nonCitizenFBLA  noVehiclesAvail  \
# 20694    1274.0         468.0      3513.0           520.0           3761.0
# 20695      81.0          70.0       146.0            59.0            347.0
# 20696     115.0          13.0       188.0             0.0            264.0
# 20697      34.0           6.0       127.0             7.0            206.0
# 20698    1608.0         737.0      2851.0           377.0           4198.0
#
#        total__18  unins__18  total_19_34  unins_19_34  total_35_64  \
# 20694     1191.0       18.0       6166.0        310.0       5215.0
# 20695      161.0        3.0        679.0          8.0        399.0
# 20696      140.0       23.0        548.0         59.0        374.0
# 20697       54.0        0.0        381.0          0.0        254.0
# 20698     3157.0      132.0      10951.0        361.0      10171.0
#
#        unins_35_64  total_65_  unins_65_  medianHHInc  healthWorkers.f  \
# 20694        111.0     2075.0        0.0     103243.0            499.0
# 20695          0.0        5.0        0.0     157125.0             26.0
# 20696          0.0      112.0        0.0     151765.0             73.0
# 20697          3.0       93.0        0.0     116250.0             14.0
# 20698        216.0     2569.0        0.0     111164.0            861.0
#
#        healthWorkers.m  employment.pop  employment.lf  employment.clf  \
# 20694            727.0         13969.0         9828.0          9804.0
# 20695            131.0          1096.0          931.0           931.0
# 20696             21.0          1118.0          819.0           819.0
# 20697             39.0           751.0          547.0           547.0
# 20698           1941.0         25321.0        18837.0         18767.0
#
#        employment.emp  commute.tot  commute.drove  commute.carpooled  \
# 20694          9212.0       9191.0         2136.0              267.0
# 20695           930.0        930.0           80.0                0.0
# 20696           754.0        754.0          141.0               44.0
# 20697           502.0        498.0           58.0               17.0
# 20698         18075.0      17689.0         5489.0              643.0
#
#        commute.transit  commute.walked  commute.other  commute.workAtHome  \
# 20694           1638.0          3977.0          461.0               712.0
# 20695            233.0           362.0           20.0               235.0
# 20696            115.0           410.0            0.0                44.0
# 20697             77.0           274.0           18.0                54.0
# 20698           5075.0          3951.0         1328.0              1203.0
#
#         ZCTA  mean_HHsize  pctHispanic  pctBlack  pctWhite  pctUndocumented  \
# 20694  60601     1.655573     0.086814  0.055741  0.741670         0.239387
# 20695  60602     2.066445     0.065113  0.037781  0.681672         0.117363
# 20696  60603     2.081560     0.097956  0.032368  0.634583         0.160136
# 20697  60604     1.632568     0.043478  0.056266  0.634271         0.162404
# 20698  60605     1.984782     0.058432  0.171772  0.612050         0.103601
#
#        pctUndocumentedFBLA  pctUninsured  pctUnemployed  pctHealthWorkers
# 20694             0.035434      0.029972       0.040341          0.083543
# 20695             0.047428      0.008842       0.000804          0.126206
# 20696             0.000000      0.069847       0.055366          0.080068
# 20697             0.008951      0.003836       0.057545          0.067775
# 20698             0.013700      0.026408       0.025146          0.101821

# %%
chicago_zips.columns
# Out:
# Index(['totalPop', 'male', 'female', 'totalHH', 'medianAge', 'race.white',
#        'race.black', 'hispanic', 'hispanic.mex', 'nonCitizen',
#        'nonCitizenFBLA', 'noVehiclesAvail', 'total__18', 'unins__18',
#        'total_19_34', 'unins_19_34', 'total_35_64', 'unins_35_64', 'total_65_',
#        'unins_65_', 'medianHHInc', 'healthWorkers.f', 'healthWorkers.m',
#        'employment.pop', 'employment.lf', 'employment.clf', 'employment.emp',
#        'commute.tot', 'commute.drove', 'commute.carpooled', 'commute.transit',
#        'commute.walked', 'commute.other', 'commute.workAtHome', 'ZCTA',
#        'mean_HHsize', 'pctHispanic', 'pctBlack', 'pctWhite', 'pctUndocumented',
#        'pctUndocumentedFBLA', 'pctUninsured', 'pctUnemployed',
#        'pctHealthWorkers'],
#       dtype='object')

# %%
census_df = chicago_zips[['ZCTA', 'totalPop', 'medianAge', 'medianHHInc', 'mean_HHsize', 'pctHispanic', 'pctBlack',
             'pctWhite', 'pctUndocumented', 'pctUndocumentedFBLA', 'pctUninsured', 'pctUnemployed',
             'pctHealthWorkers']]

# %%
census_df.shape
# Out:
# (58, 13)

# %% [markdown]
# ## Gathering Essential Worker Census Data
# The code below will be used to determine the percentage of essential workers in a given area. Essential workers are those who, during the start of the spread of COVID-19 in Chicago, were able to continue working due to the role of their work in preserving everyday necessities.

# %%
# Import list of variables necessary for analysis
worker_list = list(pd.read_excel('acs_occupation_lookup.xlsx').variable)[:-1]
worker_list = [each+'E' for each in worker_list]
worker_list = ','.join(worker_list)

# %%
# Requests occupation data through Census API from 
request_string2 = 'https://api.census.gov/data/2018/acs/acs5/subject?get={},group(S2401)&for=zip%20code%20tabulation%20area:*'.format(worker_list)
data2 = requests.get(request_string2)

# %%
df2 = pd.DataFrame(data2.json()[1:], columns = data2.json()[0])

# %%
df2.head()
# Out:
#   S2401_C01_001E S2401_C01_002E S2401_C01_003E S2401_C01_004E S2401_C01_005E  \
# 0           3564            989            344            208            136
# 1          25800           9444           4072           2543           1529
# 2          37198          21707          11310           6490           4820
# 3          15182           6793           3792           2331           1461
# 4          11384           3855           1295            771            524
#
#   S2401_C01_006E S2401_C01_007E S2401_C01_008E S2401_C01_009E S2401_C01_010E  \
# 0             80             10             30             40            225
# 1           1303            868            390             45           2830
# 2           4188           3309            666            213           3967
# 3           1128            743            254            131           1267
# 4            313            113            152             48           1577
#
#   S2401_C01_011E S2401_C01_012E S2401_C01_013E S2401_C01_014E S2401_C01_015E  \
# 0             68             19            129              9            340
# 1            618            239           1404            569           1239
# 2            532            516           2008            911           2242
# 3            341            215            508            203            606
# 4            196            110           1127            144            670
#
#   S2401_C01_016E S2401_C01_017E S2401_C01_018E S2401_C01_019E S2401_C01_020E  \
# 0            209            131            769            231             63
# 1            769            470           4847            921            409
# 2           1904            338           3448            418            252
# 3            392            214           1814            117            204
# 4            400            270           2554            375            354
#
#   S2401_C01_021E S2401_C01_022E S2401_C01_023E S2401_C01_024E S2401_C01_025E  \
# 0             44             19            202            161            112
# 1            294            115           1514           1202            801
# 2            121            131           1567            329            882
# 3            167             37            757            269            467
# 4            139            215           1054            331            440
#
#   S2401_C01_026E S2401_C01_027E S2401_C01_028E S2401_C01_029E S2401_C01_030E  \
# 0            786            428            358            263              0
# 1           5727           2294           3433           1783             43
# 2           8901           5500           3401           1327              0
# 3           4007           2036           1971            813             12
# 4           2989           1420           1569            690              0
#
#   S2401_C01_031E S2401_C01_032E S2401_C01_033E S2401_C01_034E S2401_C01_035E  \
# 0            148            115            757            279            319
# 1            930            810           3999           1167           1521
# 2            762            565           1815            668            473
# 3            503            298           1755            721            665
# 4            332            358           1296            672            282
#
#   S2401_C01_036E          GEO_ID S2401_C01_001E S2401_C01_001M S2401_C02_001E  \
# 0            159  8600000US43964           3564            321           1853
# 1           1311  8600000US28216          25800           1067          12137
# 2            674  8600000US28277          37198           1089          20009
# 3            369  8600000US28278          15182            890           7655
# 4            342  8600000US28303          11384            592           5632
#
#   S2401_C02_001M S2401_C03_001E S2401_C03_001M S2401_C04_001E S2401_C04_001M  \
# 0            196           52.0            3.3           1711            201
# 1            668           47.0            1.8          13663            736
# 2            678           53.8            1.3          17189            746
# 3            546           50.4            2.2           7527            560
# 4            465           49.5            2.6           5752            370
#
#   S2401_C05_001E S2401_C05_001M S2401_C01_002E S2401_C01_002M S2401_C02_002E  \
# 0           48.0            3.3            989            186            304
# 1           53.0            1.8           9444            610           3542
# 2           46.2            1.3          21707            756          12079
# 3           49.6            2.2           6793            449           3190
# 4           50.5            2.6           3855            347           1651
#
#    ... S2401_C01_032MA S2401_C02_032MA S2401_C02_032EA S2401_C03_032EA  \
# 0  ...            None            None            None            None
# 1  ...            None            None            None            None
# 2  ...            None            None            None            None
# 3  ...            None            None            None            None
# 4  ...            None            None            None            None
#
#   S2401_C03_032MA S2401_C04_032MA S2401_C04_032EA S2401_C05_032MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C05_032EA S2401_C01_033MA S2401_C01_033EA S2401_C02_033EA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C02_033MA S2401_C03_033EA S2401_C03_033MA S2401_C04_033MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C04_033EA S2401_C05_033MA S2401_C05_033EA S2401_C01_034EA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C01_034MA S2401_C02_034MA S2401_C02_034EA S2401_C03_034MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C03_034EA S2401_C04_034EA S2401_C04_034MA S2401_C05_034MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C05_034EA S2401_C01_035EA S2401_C01_035MA S2401_C02_035MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C02_035EA S2401_C03_035MA S2401_C03_035EA S2401_C04_035EA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C04_035MA S2401_C05_035EA S2401_C05_035MA S2401_C01_036MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C01_036EA S2401_C02_036MA S2401_C02_036EA S2401_C03_036MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C03_036EA S2401_C04_036MA S2401_C04_036EA S2401_C05_036MA  \
# 0            None            None            None            None
# 1            None            None            None            None
# 2            None            None            None            None
# 3            None            None            None            None
# 4            None            None            None            None
#
#   S2401_C05_036EA zip code tabulation area
# 0            None                    43964
# 1            None                    28216
# 2            None                    28277
# 3            None                    28278
# 4            None                    28303
#
# [5 rows x 759 columns]

# %%
# Selecting only occupations for which we have an essential indicator
essential_worker_list = pd.read_excel('acs_occupation_lookup.xlsx')
essential_worker_list.dropna(axis=0, subset=['essential','variable'], inplace=True)
essential_worker_list = essential_worker_list[essential_worker_list.essential==1]
essential_worker_list['variable'] = essential_worker_list.variable.apply(lambda x: x+'E')

# %%
# Confining the dataset to only those variables included in our variables list
df2 = pd.merge(df2.iloc[:,:36], df2.iloc[:,-1], left_index=True, right_index=True)

# %%
# Confining the dataset to just essential workers since we are mostly conserned about created pctEssential workers
df2 = pd.merge(df2.loc[:,list(essential_worker_list.variable)], df2.iloc[:,-1], left_index=True, right_index=True)

# %%
# Construct a crosswalk to change the column names
crosswalk2 = essential_worker_list[['variable', 'occupation']]
crosswalk2.set_index('variable', inplace=True)
new_col_names = []
for each in df2.columns[:-1]:
    new_col_names.append(crosswalk2.loc[each][0])

# %%
# Adding in zip code tabulation area since it's not in our excel sheet of var names
new_col_names.append('ZCTA')

# %%
# Rename columns
df2.columns = new_col_names

# %%
# Confine to Chicago zip codes only
df2_chi = df2[(df2['ZCTA']>='60601')&(df2['ZCTA']<='60701')|(df2['ZCTA']=='60707')|(df2['ZCTA']=='60827')]

# %%
# Create a new column for sum essential workers
df2_chi = df2_chi.astype(int)
df2_chi['sumEssential'] = df2_chi.iloc[:,:-1].sum(axis=1)
df2_chi.shape
# Out:
# (58, 19)

# %%
# Merge this column into larger census dataset from above to calculate percent essential workers
comm_chrs = pd.merge(census_df, df2_chi.iloc[:,-2:], on='ZCTA')

# %%
# Creating variable for percent of zip code population that is an essential worker
comm_chrs['pctEssential'] = comm_chrs.sumEssential/comm_chrs.totalPop

# %%
# Remove sumEssential since we no longer need it
comm_chrs.drop(['sumEssential'], axis=1, inplace=True)

# %%
comm_chrs
# Out:
#      ZCTA  totalPop  medianAge  medianHHInc  mean_HHsize  pctHispanic  \
# 0   60601   14675.0       34.9     103243.0     1.655573     0.086814
# 1   60602    1244.0       30.6     157125.0     2.066445     0.065113
# 2   60603    1174.0       28.9     151765.0     2.081560     0.097956
# 3   60604     782.0       32.4     116250.0     1.632568     0.043478
# 4   60605   27519.0       33.9     111164.0     1.984782     0.058432
# 5   60606    3101.0       37.2     131477.0     1.488004     0.062883
# 6   60607   29591.0       30.1      93508.0     2.307650     0.083032
# 7   60608   79205.0       32.4      44043.0     3.090686     0.506862
# 8   60609   61495.0       31.7      35179.0     2.984760     0.534352
# 9   60610   39019.0       33.6      86803.0     1.676866     0.066660
# 10  60611   32426.0       38.9     103522.0     1.564508     0.052458
# 11  60612   34311.0       31.6      41300.0     2.610790     0.122585
# 12  60613   50113.0       33.1      82321.0     1.894703     0.112985
# 13  60614   71308.0       30.3     107461.0     2.123273     0.060540
# 14  60615   41563.0       33.8      44111.0     1.967759     0.061906
# 15  60616   54464.0       36.8      45997.0     2.230577     0.084459
# 16  60617   82534.0       37.0      40265.0     2.927984     0.376560
# 17  60618   94395.0       34.4      73810.0     2.690006     0.404174
# 18  60619   61258.0       41.3      33454.0     2.335061     0.014186
# 19  60620   68096.0       40.8      35890.0     2.698047     0.013378
# 20  60621   29042.0       34.0      20991.0     2.664404     0.036533
# 21  60622   52793.0       31.7      93988.0     2.255147     0.219328
# 22  60623   85979.0       30.3      31634.0     3.438472     0.661371
# 23  60624   36158.0       30.7      22992.0     3.056208     0.052962
# 24  60625   79243.0       34.2      64117.0     2.683747     0.327827
# 25  60626   49730.0       34.0      40591.0     2.218406     0.206153
# 26  60628   66724.0       38.8      40261.0     2.901548     0.034350
# 27  60629  111850.0       31.2      42019.0     3.514312     0.710165
# 28  60630   57344.0       40.2      72092.0     2.736922     0.279140
# 29  60631   29529.0       42.6      91034.0     2.477057     0.106743
# 30  60632   91039.0       30.9      42758.0     3.653544     0.839574
# 31  60633   12871.0       38.9      47083.0     2.749039     0.449848
# 32  60634   75995.0       39.1      66741.0     2.909902     0.382459
# 33  60636   32203.0       40.0      27310.0     2.911137     0.076763
# 34  60637   47454.0       30.7      28785.0     2.467450     0.028259
# 35  60638   58797.0       37.7      67984.0     2.910887     0.517713
# 36  60639   90517.0       33.1      44150.0     3.539969     0.779279
# 37  60640   69715.0       37.3      53831.0     1.993623     0.142566
# 38  60641   71023.0       35.9      60073.0     2.866952     0.539966
# 39  60642   20201.0       31.2     101939.0     2.180827     0.201673
# 40  60643   49870.0       43.5      64477.0     2.780752     0.033066
# 41  60644   47712.0       33.3      27262.0     2.920130     0.064302
# 42  60645   47732.0       35.6      53340.0     2.936450     0.170263
# 43  60646   27987.0       43.7      89480.0     2.566673     0.141887
# 44  60647   87509.0       31.8      73443.0     2.520856     0.448251
# 45  60649   46024.0       37.7      30222.0     2.187141     0.025704
# 46  60651   63218.0       33.0      38083.0     3.216710     0.424879
# 47  60652   43907.0       35.7      68425.0     3.283994     0.398091
# 48  60653   31972.0       35.1      29569.0     2.193619     0.021550
# 49  60654   19135.0       33.1     112699.0     1.585598     0.052103
# 50  60655   28804.0       38.7      97572.0     2.815365     0.082975
# 51  60656   27579.0       40.5      61599.0     2.281519     0.122630
# 52  60657   70052.0       31.2      92295.0     1.912735     0.069962
# 53  60659   41068.0       34.7      51383.0     3.112863     0.191877
# 54  60660   43242.0       36.7      49241.0     2.091410     0.178715
# 55  60661    9926.0       30.8     107245.0     1.679242     0.064477
# 56  60707   43019.0       39.6      57554.0     2.753040     0.383668
# 57  60827   28577.0       32.7      31954.0     2.633582     0.042762
#
#     pctBlack  pctWhite  pctUndocumented  pctUndocumentedFBLA  pctUninsured  \
# 0   0.055741  0.741670         0.239387             0.035434      0.029972
# 1   0.037781  0.681672         0.117363             0.047428      0.008842
# 2   0.032368  0.634583         0.160136             0.000000      0.069847
# 3   0.056266  0.634271         0.162404             0.008951      0.003836
# 4   0.171772  0.612050         0.103601             0.013700      0.026408
# 5   0.023541  0.727507         0.108352             0.017736      0.023632
# 6   0.145112  0.581697         0.121152             0.009091      0.033990
# 7   0.176529  0.446083         0.154813             0.116483      0.151609
# 8   0.247142  0.447175         0.185869             0.162582      0.156531
# 9   0.149645  0.738179         0.063174             0.007740      0.038046
# 10  0.027540  0.749029         0.124684             0.015420      0.020385
# 11  0.604791  0.277171         0.053802             0.012562      0.082652
# 12  0.057929  0.819049         0.068166             0.018219      0.060222
# 13  0.040136  0.846090         0.056431             0.008484      0.028869
# 14  0.552222  0.301037         0.094435             0.021052      0.069929
# 15  0.250165  0.287713         0.190952             0.011035      0.091519
# 16  0.558012  0.380425         0.082439             0.075266      0.097904
# 17  0.024048  0.787669         0.149785             0.110938      0.140248
# 18  0.960789  0.016275         0.006856             0.001600      0.101698
# 19  0.964080  0.016580         0.006829             0.004185      0.098514
# 20  0.947662  0.025756         0.017389             0.012189      0.126259
# 21  0.067301  0.784460         0.067111             0.024189      0.063135
# 22  0.312332  0.383850         0.220472             0.218995      0.213823
# 23  0.908485  0.036949         0.018032             0.017285      0.120378
# 24  0.049796  0.646720         0.175599             0.107063      0.137415
# 25  0.252705  0.591957         0.152725             0.070903      0.134410
# 26  0.937474  0.044017         0.012829             0.010341      0.088447
# 27  0.197389  0.420465         0.194099             0.187966      0.151034
# 28  0.016166  0.714844         0.106393             0.043422      0.101690
# 29  0.015070  0.904772         0.031325             0.003522      0.021503
# 30  0.018563  0.517514         0.254913             0.228045      0.180299
# 31  0.232150  0.709890         0.064797             0.055163      0.122695
# 32  0.021765  0.784907         0.152813             0.063109      0.113767
# 33  0.899109  0.039624         0.027699             0.027327      0.105795
# 34  0.762064  0.161841         0.042251             0.007038      0.071315
# 35  0.031923  0.724272         0.083865             0.057724      0.086705
# 36  0.138615  0.432659         0.220334             0.208292      0.185561
# 37  0.169619  0.642745         0.114423             0.041655      0.096158
# 38  0.024077  0.682286         0.173479             0.112738      0.157202
# 39  0.103361  0.720014         0.073165             0.032375      0.062373
# 40  0.735292  0.222418         0.008061             0.004873      0.057116
# 41  0.899459  0.047724         0.016516             0.013561      0.137841
# 42  0.171101  0.568968         0.195969             0.050448      0.123491
# 43  0.010898  0.832637         0.050488             0.014542      0.060506
# 44  0.065468  0.767384         0.107326             0.086585      0.106100
# 45  0.928972  0.040479         0.021054             0.011885      0.095811
# 46  0.520627  0.166946         0.104559             0.100161      0.159765
# 47  0.471428  0.272121         0.094768             0.086979      0.084445
# 48  0.910015  0.052233         0.016514             0.002346      0.061803
# 49  0.054403  0.776953         0.057068             0.002822      0.018918
# 50  0.068602  0.894772         0.013193             0.003576      0.027184
# 51  0.012437  0.840422         0.152761             0.005439      0.098517
# 52  0.026095  0.861803         0.062868             0.011506      0.034748
# 53  0.101125  0.537304         0.219344             0.050989      0.133150
# 54  0.143518  0.655335         0.143448             0.050830      0.094701
# 55  0.035966  0.572940         0.290349             0.025589      0.031332
# 56  0.080360  0.725796         0.093447             0.046282      0.094236
# 57  0.918291  0.050565         0.009308             0.006719      0.091876
#
#     pctUnemployed  pctHealthWorkers  pctEssential
# 0        0.040341          0.083543      0.145963
# 1        0.000804          0.126206      0.245981
# 2        0.055366          0.080068      0.231687
# 3        0.057545          0.067775      0.125320
# 4        0.025146          0.101821      0.252516
# 5        0.019026          0.069332      0.253467
# 6        0.046061          0.087155      0.239025
# 7        0.038179          0.054795      0.244366
# 8        0.077551          0.048492      0.274169
# 9        0.026449          0.075784      0.235244
# 10       0.016499          0.095695      0.246160
# 11       0.057853          0.071027      0.200548
# 12       0.023088          0.071079      0.236346
# 13       0.018946          0.069109      0.191648
# 14       0.048529          0.063157      0.201381
# 15       0.039310          0.087654      0.250973
# 16       0.076308          0.059357      0.251557
# 17       0.024440          0.057747      0.249780
# 18       0.077769          0.081932      0.246368
# 19       0.088140          0.072339      0.229309
# 20       0.099821          0.049411      0.188451
# 21       0.021726          0.079783      0.252344
# 22       0.050059          0.041638      0.264099
# 23       0.066320          0.062476      0.194507
# 24       0.030223          0.074644      0.275860
# 25       0.037462          0.069897      0.267907
# 26       0.105929          0.069300      0.227759
# 27       0.081538          0.038820      0.281618
# 28       0.031390          0.069877      0.283186
# 29       0.013952          0.063903      0.308409
# 30       0.047881          0.036292      0.296587
# 31       0.051589          0.046616      0.279155
# 32       0.025515          0.065386      0.314218
# 33       0.122007          0.061764      0.205105
# 34       0.071880          0.065853      0.183335
# 35       0.040087          0.046567      0.306308
# 36       0.041694          0.054343      0.310141
# 37       0.034225          0.078921      0.235989
# 38       0.030427          0.069048      0.307084
# 39       0.031137          0.077867      0.216078
# 40       0.058091          0.067876      0.251975
# 41       0.058455          0.082243      0.243021
# 42       0.041167          0.075191      0.246187
# 43       0.027227          0.062207      0.268232
# 44       0.029700          0.064588      0.254534
# 45       0.081392          0.088975      0.244590
# 46       0.056550          0.075437      0.267819
# 47       0.060856          0.059535      0.299132
# 48       0.080915          0.079132      0.203741
# 49       0.028377          0.072694      0.218605
# 50       0.022358          0.066935      0.395987
# 51       0.027122          0.060988      0.359730
# 52       0.022826          0.075772      0.226689
# 53       0.039349          0.063845      0.271257
# 54       0.034249          0.070210      0.251214
# 55       0.025086          0.070723      0.204413
# 56       0.038216          0.061880      0.264953
# 57       0.099556          0.068062      0.250306

# %%
import pickle
pickle_out = open('census_data_zcta.pickle', 'wb')
pickle.dump(comm_chrs, pickle_out)
pickle_out.close()
